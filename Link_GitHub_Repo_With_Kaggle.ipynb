# %%
# !pip install gitpython

# %%
import shutil
import git

# %%
try:
    # Delete existing directory
    shutil.rmtree('/kaggle/working/project')
except FileNotFoundError:
    # Handle the case where the directory doesn't exist
    print("Directory doesn't exist. Nothing to delete.")
except Exception as e:
    # Handle any other exceptions
    print(f"An error occurred: {e}")
# Out:
# Directory doesn't exist. Nothing to delete.

# %%
git.Repo.clone_from('https://github.com/SEmohamedAhmed/KaggleSession.git', '/kaggle/working/project')
# Out:
# <git.repo.base.Repo '/kaggle/working/project/.git'>

# %%
# !python3 /kaggle/working/project/main.py
# Out:
# Hello, MrMody!
